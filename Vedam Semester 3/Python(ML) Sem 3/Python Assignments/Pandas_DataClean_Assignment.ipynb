# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('planets.csv')
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
t = pd.read_csv('planets.csv')
print("Rows:", t.shape[0])
print("Columns:", t.shape[1])
# Out:
# Rows: 1035
# Columns: 6

# %%
t = pd.read_csv('/Users/aareev/VS-Code/Vedam/Vedam Semester 3/Python(ML) Sem 3/Data/Titanic-Dataset.csv')
df = pd.read_csv('/Users/aareev/VS-Code/Vedam/Vedam Semester 3/Python(ML) Sem 3/Data/tip.csv')

print(df.shape, t.shape)
# Out:
# (244, 7) (891, 12)

# %%
# Question is which passenger paid highest fare in each class and what was their name.

print(t.columns)
print(df.columns)

print(t.groupby('Pclass')['Fare'].max())
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='str')
# Pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: Fare, dtype: float64

# %%
# make a tip_pct column, then average it per day

df['tip_pct'] = df['tip'] / df['total_bill'] * 100
print(df.groupby('day')['tip_pct'].mean().round(2))
# Out:
# day
# Fri     16.99
# Sat     15.32
# Sun     16.69
# Thur    16.13
# Name: tip_pct, dtype: float64

# %%
# average bill for each party size

df.groupby('size')['total_bill'].mean()
# Out:
# size
# 1     7.242500
# 2    16.448013
# 3    23.277632
# 4    28.613514
# 5    30.068000
# 6    34.830000
# Name: total_bill, dtype: float64

# %%
# Titanic file ques

# 1.1) Company report calls first class "somewhat safer". Find survival rate for each class and say in one line whether somewhat is honest.
